# %%
import polars as pl

# Load the CSV file
bike_data = pl.read_csv("./data/bike.csv")
bike_data
# Out:
# shape: (728, 18)
# ┌─────────┬────────────┬────────┬──────┬───┬─────────┬─────────┬─────────────────┬────────────┐
# │ instant ┆ dteday     ┆ season ┆ yr   ┆ … ┆ workday ┆ weather ┆ days_since_2011 ┆ cnt_2d_bfr │
# │ ---     ┆ ---        ┆ ---    ┆ ---  ┆   ┆ ---     ┆ ---     ┆ ---             ┆ ---        │
# │ i64     ┆ str        ┆ str    ┆ i64  ┆   ┆ str     ┆ str     ┆ i64             ┆ i64        │
# ╞═════════╪════════════╪════════╪══════╪═══╪═════════╪═════════╪═════════════════╪════════════╡
# │ 3       ┆ 2011-01-03 ┆ WINTER ┆ 2011 ┆ … ┆ Y       ┆ GOOD    ┆ 2               ┆ 985        │
# │ 4       ┆ 2011-01-04 ┆ WINTER ┆ 2011 ┆ … ┆ Y       ┆ GOOD    ┆ 3               ┆ 801        │
# │ 5       ┆ 2011-01-05 ┆ WINTER ┆ 2011 ┆ … ┆ Y       ┆ GOOD    ┆ 4               ┆ 1349       │
# │ 6       ┆ 2011-01-06 ┆ WINTER ┆ 2011 ┆ … ┆ Y       ┆ GOOD    ┆ 5               ┆ 1562       │
# │ 7       ┆ 2011-01-07 ┆ WINTER ┆ 2011 ┆ … ┆ Y       ┆ MISTY   ┆ 6               ┆ 1600       │
# │ …       ┆ …          ┆ …      ┆ …    ┆ … ┆ …       ┆ …       ┆ …               ┆ …          │
# │ 727     ┆ 2012-12-27 ┆ WINTER ┆ 2012 ┆ … ┆ Y       ┆ MISTY   ┆ 726             ┆ 1013       │
# │ 728     ┆ 2012-12-28 ┆ WINTER ┆ 2012 ┆ … ┆ Y       ┆ MISTY   ┆ 727             ┆ 441        │
# │ 729     ┆ 2012-12-29 ┆ WINTER ┆ 2012 ┆ … ┆ N       ┆ MISTY   ┆ 728             ┆ 2114       │
# │ 730     ┆ 2012-12-30 ┆ WINTER ┆ 2012 ┆ … ┆ N       ┆ GOOD    ┆ 729             ┆ 3095       │
# │ 731     ┆ 2012-12-31 ┆ WINTER ┆ 2012 ┆ … ┆ Y       ┆ MISTY   ┆ 730             ┆ 1341       │
# └─────────┴────────────┴────────┴──────┴───┴─────────┴─────────┴─────────────────┴────────────┘

# %%
penguins = pl.read_csv(
    "./data/penguins.csv",
    schema_overrides={
        "bill_length_mm": pl.Float64,
        "bill_depth_mm": pl.Float64,
        "flipper_length_mm": pl.Float64,
        "body_mass_g": pl.Float64,
    }
)
penguins
# Out:
# C:\Users\Beau\AppData\Local\Temp\ipykernel_95728\911933569.py:1: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   penguins = pl.read_csv(
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 penguins = pl.read_csv(
#       2     "./data/penguins.csv",
#       3     dtypes={
#       4         "bill_length_mm": pl.Float64,
#       5         "bill_depth_mm": pl.Float64,
#       6         "flipper_length_mm": pl.Float64,
#       7         "body_mass_g": pl.Float64,
#       8     }
#       9 )
#      10 penguins
#
# File c:\Dev\interpretable-ml\.venv\Lib\site-packages\polars\_utils\deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File c:\Dev\interpretable-ml\.venv\Lib\site-packages\polars\_utils\deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File c:\Dev\interpretable-ml\.venv\Lib\site-packages\polars\_utils\deprecation.py:119, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     114 @wraps(function)
#     115 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     116     _rename_keyword_argument(
#     117         old_name, new_name, kwargs, function.__qualname__, version
#     118     )
# --> 119     return function(*args, **kwargs)
#
# File c:\Dev\interpretable-ml\.venv\Lib\site-packages\polars\io\csv\functions.py:540, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     532 else:
#     533     with prepare_file_arg(
#     534         source,
#     535         encoding=encoding,
#    (...)    538         storage_options=storage_options,
#     539     ) as data:
# --> 540         df = _read_csv_impl(
#     541             data,
#     542             has_header=has_header,
#     543             columns=columns if columns else projection,
#     544             separator=separator,
#     545             comment_prefix=comment_prefix,
#     546             quote_char=quote_char,
#     547             skip_rows=skip_rows,
#     548             skip_lines=skip_lines,
#     549             schema_overrides=schema_overrides,
#     550             schema=schema,
#     551             null_values=null_values,
#     552             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     553             ignore_errors=ignore_errors,
#     554             try_parse_dates=try_parse_dates,
#     555             n_threads=n_threads,
#     556             infer_schema_length=infer_schema_length,
#     557             batch_size=batch_size,
#     558             n_rows=n_rows,
#     559             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     560             low_memory=low_memory,
#     561             rechunk=rechunk,
#     562             skip_rows_after_header=skip_rows_after_header,
#     563             row_index_name=row_index_name,
#     564             row_index_offset=row_index_offset,
#     565             eol_char=eol_char,
#     566             raise_if_empty=raise_if_empty,
#     567             truncate_ragged_lines=truncate_ragged_lines,
#     568             decimal_comma=decimal_comma,
#     569             glob=glob,
#     570         )
#     572 if new_columns:
#     573     return _update_columns(df, new_columns)
#
# File c:\Dev\interpretable-ml\.venv\Lib\site-packages\polars\io\csv\functions.py:688, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     684         raise ValueError(msg)
#     686 projection, columns = parse_columns_arg(columns)
# --> 688 pydf = PyDataFrame.read_csv(
#     689     source,
#     690     infer_schema_length,
#     691     batch_size,
#     692     has_header,
#     693     ignore_errors,
#     694     n_rows,
#     695     skip_rows,
#     696     skip_lines,
#     697     projection,
#     698     separator,
#     699     rechunk,
#     700     columns,
#     701     encoding,
#     702     n_threads,
#     703     path,
#     704     dtype_list,
#     705     dtype_slice,
#     706     low_memory,
#     707     comment_prefix,
#     708     quote_char,
#     709     processed_null_values,
#     710     missing_utf8_is_empty_string,
#     711     try_parse_dates,
#     712     skip_rows_after_header,
#     713     parse_row_index_args(row_index_name, row_index_offset),
#     714     eol_char=eol_char,
#     715     raise_if_empty=raise_if_empty,
#     716     truncate_ragged_lines=truncate_ragged_lines,
#     717     decimal_comma=decimal_comma,
#     718     schema=schema,
#     719 )
#     720 return wrap_df(pydf)
#
# ComputeError: could not parse `NA` as dtype `f64` at column 'bill_length_mm' (column number 4)
#
# The current offset in the file is 195 bytes.
#
# You might want to try:
# - increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),
# - specifying correct dtype with the `schema_overrides` argument
# - setting `ignore_errors` to `True`,
# - adding `NA` to the `null_values` list.
#
# Original error: ```remaining bytes non-empty```
